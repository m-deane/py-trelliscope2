# %% [markdown]
# # Real-World Use Case: Financial Portfolio Analysis
#
# This notebook demonstrates a **complete real-world workflow** combining all Trelliscope features.
#
# ## Scenario: Portfolio Manager Dashboard
#
# You manage a diversified portfolio of 60 assets across:
# - **Asset Classes**: Stocks, Bonds, Commodities, Real Estate, Crypto
# - **Regions**: North America, Europe, Asia, Emerging Markets
# - **Risk Profiles**: Conservative, Moderate, Aggressive
#
# **Goals**:
# 1. Monitor performance across all assets
# 2. Identify underperformers and star performers
# 3. Analyze risk-return profiles
# 4. Track sector correlations
# 5. Generate client reports
#
# ## Features Demonstrated (Complete Integration)
#
# - ✅ **Plotly Interactive Charts** - Hover for detailed metrics
# - ✅ **Mixed Visualizations** - Plotly candlesticks + matplotlib heatmaps
# - ✅ **Advanced Filtering** - Multi-dimensional asset screening
# - ✅ **Keyboard Navigation** - Rapid portfolio scanning
# - ✅ **Saved Views** - "Top Performers", "High Risk", "Sector Analysis"
# - ✅ **CSV Export** - Client reports and detailed analysis
# - ✅ **Panel Details Modal** - Full-size chart analysis
#
# ## Generated Visualizations
#
# Each asset gets:
# 1. **Plotly Candlestick**: Interactive price history with volume
# 2. **Matplotlib Returns Dist**: Statistical analysis with Q-Q plot
# 3. Comprehensive metrics: Sharpe ratio, max drawdown, volatility, etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from pathlib import Path
import sys
from datetime import datetime, timedelta
from scipy import stats

sys.path.insert(0, str(Path.cwd().parent.parent))

from trelliscope import Display
from trelliscope.dash_viewer import create_dash_app

plt.style.use('seaborn-v0_8-darkgrid')
np.random.seed(42)

# %% [markdown]
# ## Generate Realistic Financial Data

# %%
# Asset universe
asset_classes = ['Stocks', 'Bonds', 'Commodities', 'Real Estate', 'Crypto']
regions = ['North America', 'Europe', 'Asia', 'Emerging Markets']
risk_profiles = ['Conservative', 'Moderate', 'Aggressive']

n_assets = 60
n_days = 252  # Trading year

print(f"Generating {n_assets} assets with {n_days} days of price history...\n")

start_date = datetime(2024, 1, 1)
dates = [start_date + timedelta(days=i) for i in range(n_days)]

portfolio_data = []

for i in range(n_assets):
    ticker = f'ASSET{i+1:02d}'
    asset_class = asset_classes[i % len(asset_classes)]
    region = regions[i % len(regions)]
    
    # Risk characteristics vary by asset class
    if asset_class == 'Stocks':
        volatility = np.random.uniform(0.15, 0.35)
        expected_return = np.random.uniform(0.08, 0.20)
    elif asset_class == 'Bonds':
        volatility = np.random.uniform(0.03, 0.10)
        expected_return = np.random.uniform(0.02, 0.06)
    elif asset_class == 'Commodities':
        volatility = np.random.uniform(0.20, 0.40)
        expected_return = np.random.uniform(0.00, 0.15)
    elif asset_class == 'Real Estate':
        volatility = np.random.uniform(0.10, 0.20)
        expected_return = np.random.uniform(0.05, 0.12)
    else:  # Crypto
        volatility = np.random.uniform(0.40, 0.80)
        expected_return = np.random.uniform(-0.10, 0.50)
    
    # Generate price series using geometric Brownian motion
    dt = 1/252  # Daily
    drift = (expected_return - 0.5 * volatility**2) * dt
    shock = volatility * np.sqrt(dt) * np.random.randn(n_days)
    
    log_returns = drift + shock
    returns = np.exp(log_returns)
    
    initial_price = np.random.uniform(50, 500)
    prices = initial_price * np.cumprod(returns)
    
    # Generate OHLCV data
    highs = prices * (1 + np.abs(np.random.randn(n_days) * 0.02))
    lows = prices * (1 - np.abs(np.random.randn(n_days) * 0.02))
    opens = np.roll(prices, 1)
    opens[0] = prices[0]
    volumes = np.random.lognormal(15, 1, n_days)
    
    # Calculate metrics
    daily_returns = np.diff(prices) / prices[:-1]
    
    total_return = (prices[-1] - prices[0]) / prices[0] * 100
    ann_return = ((prices[-1] / prices[0]) ** (252 / n_days) - 1) * 100
    ann_volatility = np.std(daily_returns) * np.sqrt(252) * 100
    sharpe_ratio = (ann_return - 2.0) / ann_volatility if ann_volatility > 0 else 0  # Risk-free = 2%
    
    # Max drawdown
    cummax = np.maximum.accumulate(prices)
    drawdown = (prices - cummax) / cummax * 100
    max_drawdown = np.min(drawdown)
    
    # Risk profile
    if sharpe_ratio > 1.0 and ann_volatility < 15:
        risk_profile = 'Conservative'
    elif sharpe_ratio > 0.5 and ann_volatility < 25:
        risk_profile = 'Moderate'
    else:
        risk_profile = 'Aggressive'
    
    # Performance tier
    if total_return > 20:
        tier = 'Star'
    elif total_return > 5:
        tier = 'Good'
    elif total_return > -5:
        tier = 'Neutral'
    else:
        tier = 'Underperformer'
    
    portfolio_data.append({
        'ticker': ticker,
        'asset_class': asset_class,
        'region': region,
        'risk_profile': risk_profile,
        'performance_tier': tier,
        'total_return': total_return,
        'ann_return': ann_return,
        'ann_volatility': ann_volatility,
        'sharpe_ratio': sharpe_ratio,
        'max_drawdown': max_drawdown,
        'current_price': prices[-1],
        # Store data for charts
        'dates': dates,
        'prices': prices,
        'opens': opens,
        'highs': highs,
        'lows': lows,
        'volumes': volumes,
        'returns': daily_returns
    })
    
    if (i + 1) % 15 == 0:
        print(f"  Generated {i+1}/{n_assets} assets...")

print(f"\n✓ Generated {len(portfolio_data)} assets with complete price history")
# Out:
# Generating 60 assets with 252 days of price history...
#
#   Generated 15/60 assets...
#   Generated 30/60 assets...
#   Generated 45/60 assets...
#   Generated 60/60 assets...
#
# ✓ Generated 60 assets with complete price history

# %%
# Quick stats
df_temp = pd.DataFrame([{k: v for k, v in asset.items() if k not in ['dates', 'prices', 'opens', 'highs', 'lows', 'volumes', 'returns']} 
                        for asset in portfolio_data])

print("Portfolio Summary:\n")
print(f"By Asset Class:")
print(df_temp.groupby('asset_class')['total_return'].agg(['count', 'mean', 'std']).round(2))

print(f"\nBy Performance Tier:")
print(df_temp['performance_tier'].value_counts())
# Out:
# Portfolio Summary:
#
# By Asset Class:
#              count   mean    std
# asset_class
# Bonds           12   6.34   4.07
# Commodities     12   5.43  38.64
# Crypto          12  19.89  63.25
# Real Estate     12  15.01  13.52
# Stocks          12  17.11  29.18
#
# By Performance Tier:
# performance_tier
# Star              20
# Good              16
# Underperformer    15
# Neutral            9
# Name: count, dtype: int64

# %% [markdown]
# ## Create Visualization Functions

# %%
def create_plotly_candlestick(asset_data):
    """
    Interactive Plotly candlestick chart with volume.
    
    Features: Hover details, zoom, pan, range selector
    """
    ticker = asset_data['ticker']
    dates = asset_data['dates']
    
    fig = make_subplots(
        rows=2, cols=1,
        row_heights=[0.7, 0.3],
        vertical_spacing=0.05,
        subplot_titles=('Price', 'Volume'),
        shared_xaxes=True
    )
    
    # Candlestick
    fig.add_trace(
        go.Candlestick(
            x=dates,
            open=asset_data['opens'],
            high=asset_data['highs'],
            low=asset_data['lows'],
            close=asset_data['prices'],
            name='Price',
            increasing_line_color='#26a69a',
            decreasing_line_color='#ef5350'
        ),
        row=1, col=1
    )
    
    # Volume bars
    colors = ['#26a69a' if asset_data['prices'][i] >= asset_data['opens'][i] else '#ef5350' 
              for i in range(len(dates))]
    
    fig.add_trace(
        go.Bar(
            x=dates,
            y=asset_data['volumes'],
            name='Volume',
            marker_color=colors,
            showlegend=False
        ),
        row=2, col=1
    )
    
    # Add performance metrics as annotation
    metrics_text = (
        f"Return: {asset_data['total_return']:.1f}% | "
        f"Volatility: {asset_data['ann_volatility']:.1f}% | "
        f"Sharpe: {asset_data['sharpe_ratio']:.2f}"
    )
    
    fig.add_annotation(
        text=metrics_text,
        xref='paper', yref='paper',
        x=0.5, y=1.12,
        showarrow=False,
        font=dict(size=11, color='#666'),
        align='center'
    )
    
    fig.update_layout(
        title=f"{ticker} - {asset_data['asset_class']} ({asset_data['region']})",
        xaxis_rangeslider_visible=False,
        height=550,
        hovermode='x unified',
        plot_bgcolor='white',
        paper_bgcolor='white'
    )
    
    fig.update_xaxes(showgrid=True, gridcolor='#e0e0e0')
    fig.update_yaxes(showgrid=True, gridcolor='#e0e0e0')
    
    return fig


def create_matplotlib_returns_analysis(asset_data):
    """
    Statistical returns analysis with matplotlib.
    
    Panels: Returns distribution, Q-Q plot, rolling volatility, drawdown
    """
    ticker = asset_data['ticker']
    returns = asset_data['returns'] * 100  # Convert to %
    dates = asset_data['dates'][1:]  # Returns are 1 day shorter
    prices = asset_data['prices']
    
    fig = plt.figure(figsize=(12, 9))
    gs = gridspec.GridSpec(2, 2, hspace=0.3, wspace=0.3)
    
    # 1. Returns histogram with normal fit
    ax1 = fig.add_subplot(gs[0, 0])
    ax1.hist(returns, bins=40, alpha=0.7, color='steelblue', edgecolor='black', density=True)
    
    # Fit normal distribution
    mu, sigma = returns.mean(), returns.std()
    x = np.linspace(returns.min(), returns.max(), 100)
    ax1.plot(x, stats.norm.pdf(x, mu, sigma), 'r-', linewidth=2, label=f'Normal(μ={mu:.2f}, σ={sigma:.2f})')
    
    ax1.set_xlabel('Daily Return (%)')
    ax1.set_ylabel('Density')
    ax1.set_title('Returns Distribution')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    
    # 2. Q-Q plot
    ax2 = fig.add_subplot(gs[0, 1])
    stats.probplot(returns, dist="norm", plot=ax2)
    ax2.set_title('Q-Q Plot (Normality Test)')
    ax2.grid(True, alpha=0.3)
    
    # 3. Rolling volatility
    ax3 = fig.add_subplot(gs[1, 0])
    rolling_vol = pd.Series(returns).rolling(window=20).std() * np.sqrt(252)
    ax3.plot(dates, rolling_vol, linewidth=1.5, color='darkorange')
    ax3.axhline(asset_data['ann_volatility'], color='red', linestyle='--', linewidth=1, label=f'Annual: {asset_data["ann_volatility"]:.1f}%')
    ax3.set_xlabel('Date')
    ax3.set_ylabel('Annualized Volatility (%)')
    ax3.set_title('Rolling 20-Day Volatility')
    ax3.legend()
    ax3.grid(True, alpha=0.3)
    ax3.tick_params(axis='x', rotation=45)
    
    # 4. Drawdown chart
    ax4 = fig.add_subplot(gs[1, 1])
    cummax = np.maximum.accumulate(prices)
    drawdown = (prices - cummax) / cummax * 100
    
    ax4.fill_between(asset_data['dates'], drawdown, 0, color='red', alpha=0.3)
    ax4.plot(asset_data['dates'], drawdown, color='darkred', linewidth=1.5)
    ax4.axhline(asset_data['max_drawdown'], color='red', linestyle='--', linewidth=1, 
                label=f'Max DD: {asset_data["max_drawdown"]:.1f}%')
    ax4.set_xlabel('Date')
    ax4.set_ylabel('Drawdown (%)')
    ax4.set_title('Underwater Chart')
    ax4.legend()
    ax4.grid(True, alpha=0.3)
    ax4.tick_params(axis='x', rotation=45)
    
    fig.suptitle(f'{ticker} - Statistical Analysis', fontsize=14, fontweight='bold', y=0.995)
    
    return fig


print("✓ Created visualization functions (Plotly + Matplotlib)")
# Out:
# ✓ Created visualization functions (Plotly + Matplotlib)

# %% [markdown]
# ## Generate All Panels
#
# Each asset gets 2 panels:
# 1. Plotly candlestick (interactive)
# 2. Matplotlib statistical analysis (static)

# %%
print(f"Generating {n_assets * 2} panels (candlestick + returns analysis)...\n")

final_data = []

for i, asset in enumerate(portfolio_data):
    # Common metadata
    base_data = {
        'ticker': asset['ticker'],
        'asset_class': asset['asset_class'],
        'region': asset['region'],
        'risk_profile': asset['risk_profile'],
        'performance_tier': asset['performance_tier'],
        'total_return': asset['total_return'],
        'ann_return': asset['ann_return'],
        'ann_volatility': asset['ann_volatility'],
        'sharpe_ratio': asset['sharpe_ratio'],
        'max_drawdown': asset['max_drawdown'],
        'current_price': asset['current_price']
    }
    
    # Plotly candlestick
    plotly_fig = create_plotly_candlestick(asset)
    final_data.append({
        **base_data,
        'chart_type': 'Candlestick',
        'format': 'Interactive (Plotly)',
        'panel': plotly_fig
    })
    
    # Matplotlib statistical
    mpl_fig = create_matplotlib_returns_analysis(asset)
    final_data.append({
        **base_data,
        'chart_type': 'Statistical Analysis',
        'format': 'Static (Matplotlib)',
        'panel': mpl_fig
    })
    plt.close(mpl_fig)
    
    if (i + 1) % 15 == 0:
        print(f"  Generated {(i+1)*2}/{n_assets*2} panels...")

final_df = pd.DataFrame(final_data)
print(f"\n✓ Generated {len(final_df)} panels")
print(f"  - Plotly (interactive): {len(final_df[final_df['format'] == 'Interactive (Plotly)'])}")
print(f"  - Matplotlib (static): {len(final_df[final_df['format'] == 'Static (Matplotlib)'])}")
# Out:
# Generating 120 panels (candlestick + returns analysis)...
#
#   Generated 30/120 panels...
#   Generated 60/120 panels...
#   Generated 90/120 panels...
#   Generated 120/120 panels...
#
# ✓ Generated 120 panels
#   - Plotly (interactive): 60
#   - Matplotlib (static): 60

# %% [markdown]
# ## Create Portfolio Display

# %%
display = (
    Display(
        final_df,
        name="financial_portfolio_dashboard",
        description="Complete Portfolio Analysis - 60 Assets with Interactive Candlesticks & Statistical Analysis"
    )
    .set_panel_column("panel")
    .infer_metas()
    .set_default_layout(ncol=2, nrow=2)  # 4 panels per page
    .set_default_labels(["ticker", "asset_class", "performance_tier", "sharpe_ratio"])
)

print("✓ Portfolio display configured")
print(f"  Assets: {n_assets}")
print(f"  Total panels: {len(final_df)}")
print(f"  Asset classes: {final_df['asset_class'].nunique()}")
print(f"  Performance tiers: {final_df['performance_tier'].nunique()}")
# Out:
# ✓ Portfolio display configured
#   Assets: 60
#   Total panels: 120
#   Asset classes: 5
#   Performance tiers: 4

# %% [markdown]
# ## Launch Portfolio Dashboard
#
# ### 🎯 Complete Workflow: Portfolio Review
#
# #### **Morning Portfolio Check** (5 minutes)
#
# **1. Star Performers View**
# ```
# Filter: performance_tier = "Star"
# Filter: chart_type = "Candlestick"
# Sort: total_return (descending)
# Save View: "Morning - Top Performers"
# ```
# → Quick scan of best assets with interactive charts
#
# **2. Risk Assessment**
# ```
# Filter: performance_tier = "Underperformer"
# Filter: chart_type = "Statistical Analysis"
# Sort: max_drawdown (ascending)
# Save View: "Morning - Risk Check"
# ```
# → Review statistical diagnostics for underperformers
#
# **3. High Volatility Assets**
# ```
# Filter: ann_volatility > 30
# Filter: chart_type = "Candlestick"
# Save View: "High Vol Monitoring"
# ```
#
# ---
#
# #### **Client Reporting** (10 minutes)
#
# **Conservative Portfolio Report**
# ```
# Filter: risk_profile = "Conservative"
# Filter: chart_type = "Candlestick"
# Export CSV → conservative_holdings.csv
# Open in Excel → Client presentation
# ```
#
# **Sector Analysis - Technology**
# ```
# Search: "Stocks" (global search)
# Filter: region = "North America"
# Sort: sharpe_ratio (descending)
# Export View JSON → tech_sector_config.json
# Share config with team
# ```
#
# ---
#
# #### **Deep Dive Analysis** (15 minutes)
#
# **1. Interactive Exploration**
# ```
# - Load "Star Performers" view
# - Click any candlestick panel → Full-size modal
# - Hover over candles → Detailed OHLC data
# - Zoom into recent volatility spike
# - Press → to see next panel in modal
# ```
#
# **2. Statistical Verification**
# ```
# - Filter: Same ticker
# - Filter: chart_type = "Statistical Analysis"
# - Examine Q-Q plot for normality
# - Check drawdown chart
# - Review rolling volatility trends
# ```
#
# **3. Comparative Analysis**
# ```
# Filter: asset_class = "Crypto"
# Sort: sharpe_ratio (descending)
# → → → Navigate pages to see all crypto assets
# + + + Increase grid to see more at once
# ```
#
# ---
#
# ### 💼 Pre-Configured Views (Create These)
#
# 1. **"Daily Dashboard"**
#    - All star + good performers
#    - Candlestick charts only
#    - Sorted by total return
#
# 2. **"Risk Review"**
#    - All aggressive + underperformers
#    - Statistical analysis charts
#    - Sorted by max drawdown
#
# 3. **"Emerging Markets"**
#    - Region = "Emerging Markets"
#    - All chart types
#    - Sorted by sharpe ratio
#
# 4. **"Crypto Watch"**
#    - Asset class = "Crypto"
#    - Candlestick only
#    - Sorted by ann_volatility
#
# 5. **"Conservative Holdings"**
#    - Risk profile = "Conservative"
#    - Statistical analysis
#    - Export ready for client reports
#
# ---
#
# ### 🚀 Power User Shortcuts
#
# ```
# / → Type "Star"           Quick filter to star performers
# → → → → →                 Rapid page scanning
# End                       Jump to end of results
# Ctrl+S                    Save current view
# + + +                     Increase grid to 3×3
# Click panel               Full-size interactive analysis
# Ctrl+R                    Reset to start fresh
# ```
#
# ---
#
# ### 📊 Expected Insights
#
# From this portfolio, you should discover:
# - **Star performers**: High Sharpe ratio assets worth increasing allocation
# - **Underperformers**: Assets with negative returns or poor risk-adjusted returns
# - **Volatility clusters**: Crypto and commodities will show higher ann_volatility
# - **Drawdown patterns**: Some assets recovered quickly, others still underwater
# - **Regional differences**: Emerging markets may show higher risk but mixed returns
#
# ---
#
# The viewer opens at http://localhost:8058
#
# **This is your complete portfolio management command center!**

# %%
app = create_dash_app(display)
app.run(debug=False, host='127.0.0.1', port=8058)
# Out:
# Rendering 120 panels...
#   Rendered panel 0: 0.html
#   Rendered panel 1: 1.png
#   Rendered panel 2: 2.html
#   Rendered panel 3: 3.png
#   Rendered panel 4: 4.html
#   Rendered panel 5: 5.png
#   Rendered panel 6: 6.html
#   Rendered panel 7: 7.png
#   Rendered panel 8: 8.html
#   Rendered panel 9: 9.png
#   Rendered panel 10: 10.html
#   Rendered panel 11: 11.png
#   Rendered panel 12: 12.html
#   Rendered panel 13: 13.png
#   Rendered panel 14: 14.html
#   Rendered panel 15: 15.png
#   Rendered panel 16: 16.html
#   Rendered panel 17: 17.png
#   Rendered panel 18: 18.html
#   Rendered panel 19: 19.png
#   Rendered panel 20: 20.html
#   Rendered panel 21: 21.png
#   Rendered panel 22: 22.html
#   Rendered panel 23: 23.png
#   Rendered panel 24: 24.html
#   Rendered panel 25: 25.png
#   Rendered panel 26: 26.html
#   Rendered panel 27: 27.png
#   Rendered panel 28: 28.html
#   Rendered panel 29: 29.png
#   Rendered panel 30: 30.html
#   Rendered panel 31: 31.png
#   Rendered panel 32: 32.html
#   Rendered panel 33: 33.png
#   Rendered panel 34: 34.html
#   Rendered panel 35: 35.png
#   Rendered panel 36: 36.html
#   Rendered panel 37: 37.png
#   Rendered panel 38: 38.html
#   Rendered panel 39: 39.png
#   Rendered panel 40: 40.html
#   Rendered panel 41: 41.png
#   Rendered panel 42: 42.html
#   Rendered panel 43: 43.png
#   Rendered panel 44: 44.html
#   Rendered panel 45: 45.png
#   Rendered panel 46: 46.html
#   Rendered panel 47: 47.png
#   Rendered panel 48: 48.html
#   Rendered panel 49: 49.png
#   Rendered panel 50: 50.html
#   Rendered panel 51: 51.png
#   Rendered panel 52: 52.html
#   Rendered panel 53: 53.png
#   Rendered panel 54: 54.html
#   Rendered panel 55: 55.png
#   Rendered panel 56: 56.html
#   Rendered panel 57: 57.png
#   Rendered panel 58: 58.html
#   Rendered panel 59: 59.png
#   Rendered panel 60: 60.html
#   Rendered panel 61: 61.png
#   Rendered panel 62: 62.html
#   Rendered panel 63: 63.png
#   Rendered panel 64: 64.html
#   Rendered panel 65: 65.png
#   Rendered panel 66: 66.html
#   Rendered panel 67: 67.png
#   Rendered panel 68: 68.html
#   Rendered panel 69: 69.png
#   Rendered panel 70: 70.html
#   Rendered panel 71: 71.png
#   Rendered panel 72: 72.html
#   Rendered panel 73: 73.png
#   Rendered panel 74: 74.html
#   Rendered panel 75: 75.png
#   Rendered panel 76: 76.html
#   Rendered panel 77: 77.png
#   Rendered panel 78: 78.html
#   Rendered panel 79: 79.png
#   Rendered panel 80: 80.html
#   Rendered panel 81: 81.png
#   Rendered panel 82: 82.html
#   Rendered panel 83: 83.png
#   Rendered panel 84: 84.html
#   Rendered panel 85: 85.png
#   Rendered panel 86: 86.html
#   Rendered panel 87: 87.png
#   Rendered panel 88: 88.html
#   Rendered panel 89: 89.png
#   Rendered panel 90: 90.html
#   Rendered panel 91: 91.png
#   Rendered panel 92: 92.html
#   Rendered panel 93: 93.png
#   Rendered panel 94: 94.html
#   Rendered panel 95: 95.png
#   Rendered panel 96: 96.html
#   Rendered panel 97: 97.png
#   Rendered panel 98: 98.html
#   Rendered panel 99: 99.png
#   Rendered panel 100: 100.html
#   Rendered panel 101: 101.png
#   Rendered panel 102: 102.html
#   Rendered panel 103: 103.png
#   Rendered panel 104: 104.html
#   Rendered panel 105: 105.png
#   Rendered panel 106: 106.html
#   Rendered panel 107: 107.png
#   Rendered panel 108: 108.html
#   Rendered panel 109: 109.png
#   Rendered panel 110: 110.html
#   Rendered panel 111: 111.png
#   Rendered panel 112: 112.html
#   Rendered panel 113: 113.png
#   Rendered panel 114: 114.html
#   Rendered panel 115: 115.png
#   Rendered panel 116: 116.html
#   Rendered panel 117: 117.png
#   Rendered panel 118: 118.html
#   Rendered panel 119: 119.png
#   Generated index.html viewer at trelliscope_output/financial_portfolio_dashboard
# 🚀 Dash viewer starting on http://127.0.0.1:8058
# 📊 Display: financial_portfolio_dashboard
# 📈 Panels: 120
#
# ✨ Opening browser...
#  * Serving Flask app 'trelliscope.dash_viewer.app'
#  * Debug mode: off
# [DEBUG FILTERS] Total filterable_metas: 13
# [DEBUG FILTERS] Meta varnames: ['ann_return', 'ann_volatility', 'asset_class', 'chart_type', 'current_price', 'format', 'max_drawdown', 'performance_tier', 'region', 'risk_profile', 'sharpe_ratio', 'ticker', 'total_return']
# [DEBUG FILTERS] Meta types: ['number', 'number', 'factor', 'factor', 'number', 'factor', 'number', 'factor', 'factor', 'factor', 'number', 'factor', 'number']
# [DEBUG FILTERS] cog_data columns: ['ticker', 'asset_class', 'region', 'risk_profile', 'performance_tier', 'total_return', 'ann_return', 'ann_volatility', 'sharpe_ratio', 'max_drawdown', 'current_price', 'chart_type', 'format', 'panelKey', 'panel', 'asset_class_label', 'chart_type_label', 'format_label', 'performance_tier_label', 'region_label', 'risk_profile_label', 'ticker_label', '_panel_full_path', '_panel_type']
# [DEBUG FILTERS] Processing ann_return (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for ann_return (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for ann_return: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for ann_return (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for ann_return: filter_comp=Div([RangeSlider(min=-66.84674812113609, max=129.59153569308634, marks={-66.84674812113609: '-66.85', 129.59153569308634: '129.59', 31.372393785975127: '31.37'}, value=[-66.84674812113609, 129.59153569308634], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'ann_return'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for ann_return (type: number). Total cards now: 1
# [DEBUG FILTERS] Processing ann_volatility (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for ann_volatility (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for ann_volatility: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for ann_volatility (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for ann_volatility: filter_comp=Div([RangeSlider(min=3.230216157969125, max=75.81604815964553, marks={3.230216157969125: '3.23', 75.81604815964553: '75.82', 39.52313215880733: '39.52'}, value=[3.230216157969125, 75.81604815964553], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'ann_volatility'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for ann_volatility (type: number). Total cards now: 2
# [DEBUG FILTERS] Factor asset_class: using label column asset_class_label
# [DEBUG FILTERS] >>> About to call create_filter_component for asset_class (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for asset_class: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for asset_class (type: factor)
# [DEBUG FILTERS] asset_class dropdown has 5 options
# [DEBUG FILTERS] asset_class component id: {'type': 'filter', 'varname': 'asset_class'}
# [DEBUG FILTERS] >>> About to check if filter_comp for asset_class: filter_comp=Dropdown(options=[{'label': 'Bonds (24)', 'value': 'Bonds'}, {'label': 'Commodities (24)', 'value': 'Commodities'}, {'label': 'Crypto (24)', 'value': 'Crypto'}, {'label': 'Real Estate (24)', 'value': 'Real Estate'}, {'label': 'Stocks (24)', 'value': 'Stocks'}], multi=True, placeholder='Select asset_class...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'asset_class'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for asset_class (type: factor). Total cards now: 3
# [DEBUG FILTERS] Factor chart_type: using label column chart_type_label
# [DEBUG FILTERS] >>> About to call create_filter_component for chart_type (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for chart_type: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for chart_type (type: factor)
# [DEBUG FILTERS] chart_type dropdown has 2 options
# [DEBUG FILTERS] chart_type component id: {'type': 'filter', 'varname': 'chart_type'}
# [DEBUG FILTERS] >>> About to check if filter_comp for chart_type: filter_comp=Dropdown(options=[{'label': 'Candlestick (60)', 'value': 'Candlestick'}, {'label': 'Statistical Analysis (60)', 'value': 'Statistical Analysis'}], multi=True, placeholder='Select chart_type...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'chart_type'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for chart_type (type: factor). Total cards now: 4
# [DEBUG FILTERS] Processing current_price (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for current_price (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for current_price: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for current_price (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for current_price: filter_comp=Div([RangeSlider(min=24.216837991198876, max=677.9581094089157, marks={24.216837991198876: '24.22', 677.9581094089157: '677.96', 351.0874737000573: '351.09'}, value=[24.216837991198876, 677.9581094089157], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'current_price'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for current_price (type: number). Total cards now: 5
# [DEBUG FILTERS] Factor format: using label column format_label
# [DEBUG FILTERS] >>> About to call create_filter_component for format (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for format: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for format (type: factor)
# [DEBUG FILTERS] format dropdown has 2 options
# [DEBUG FILTERS] format component id: {'type': 'filter', 'varname': 'format'}
# [DEBUG FILTERS] >>> About to check if filter_comp for format: filter_comp=Dropdown(options=[{'label': 'Interactive (Plotly) (60)', 'value': 'Interactive (Plotly)'}, {'label': 'Static (Matplotlib) (60)', 'value': 'Static (Matplotlib)'}], multi=True, placeholder='Select format...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'format'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for format (type: factor). Total cards now: 6
# [DEBUG FILTERS] Processing max_drawdown (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for max_drawdown (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for max_drawdown: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for max_drawdown (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for max_drawdown: filter_comp=Div([RangeSlider(min=-74.36654525600242, max=-2.0972304788231138, marks={-74.36654525600242: '-74.37', -2.0972304788231138: '-2.10', -38.231887867412766: '-38.23'}, value=[-74.36654525600242, -2.0972304788231138], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'max_drawdown'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for max_drawdown (type: number). Total cards now: 7
# [DEBUG FILTERS] Factor performance_tier: using label column performance_tier_label
# [DEBUG FILTERS] >>> About to call create_filter_component for performance_tier (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for performance_tier: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for performance_tier (type: factor)
# [DEBUG FILTERS] performance_tier dropdown has 4 options
# [DEBUG FILTERS] performance_tier component id: {'type': 'filter', 'varname': 'performance_tier'}
# [DEBUG FILTERS] >>> About to check if filter_comp for performance_tier: filter_comp=Dropdown(options=[{'label': 'Good (32)', 'value': 'Good'}, {'label': 'Neutral (18)', 'value': 'Neutral'}, {'label': 'Star (40)', 'value': 'Star'}, {'label': 'Underperformer (30)', 'value': 'Underperformer'}], multi=True, placeholder='Select performance_tier...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'performance_tier'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for performance_tier (type: factor). Total cards now: 8
# [DEBUG FILTERS] Factor region: using label column region_label
# [DEBUG FILTERS] >>> About to call create_filter_component for region (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for region: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for region (type: factor)
# [DEBUG FILTERS] region dropdown has 4 options
# [DEBUG FILTERS] region component id: {'type': 'filter', 'varname': 'region'}
# [DEBUG FILTERS] >>> About to check if filter_comp for region: filter_comp=Dropdown(options=[{'label': 'Asia (30)', 'value': 'Asia'}, {'label': 'Emerging Markets (30)', 'value': 'Emerging Markets'}, {'label': 'Europe (30)', 'value': 'Europe'}, {'label': 'North America (30)', 'value': 'North America'}], multi=True, placeholder='Select region...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'region'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for region (type: factor). Total cards now: 9
# [DEBUG FILTERS] Factor risk_profile: using label column risk_profile_label
# [DEBUG FILTERS] >>> About to call create_filter_component for risk_profile (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for risk_profile: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for risk_profile (type: factor)
# [DEBUG FILTERS] risk_profile dropdown has 3 options
# [DEBUG FILTERS] risk_profile component id: {'type': 'filter', 'varname': 'risk_profile'}
# [DEBUG FILTERS] >>> About to check if filter_comp for risk_profile: filter_comp=Dropdown(options=[{'label': 'Aggressive (84)', 'value': 'Aggressive'}, {'label': 'Conservative (12)', 'value': 'Conservative'}, {'label': 'Moderate (24)', 'value': 'Moderate'}], multi=True, placeholder='Select risk_profile...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'risk_profile'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for risk_profile (type: factor). Total cards now: 10
# [DEBUG FILTERS] Processing sharpe_ratio (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for sharpe_ratio (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for sharpe_ratio: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for sharpe_ratio (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for sharpe_ratio: filter_comp=Div([RangeSlider(min=-1.9286361179028848, max=4.102756392074044, marks={-1.9286361179028848: '-1.93', 4.102756392074044: '4.10', 1.0870601370855795: '1.09'}, value=[-1.9286361179028848, 4.102756392074044], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'sharpe_ratio'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for sharpe_ratio (type: number). Total cards now: 11
# [DEBUG FILTERS] Factor ticker: using label column ticker_label
# [DEBUG FILTERS] >>> About to call create_filter_component for ticker (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for ticker: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for ticker (type: factor)
# [DEBUG FILTERS] ticker dropdown has 60 options
# [DEBUG FILTERS] ticker component id: {'type': 'filter', 'varname': 'ticker'}
# [DEBUG FILTERS] >>> About to check if filter_comp for ticker: filter_comp=Dropdown(options=[{'label': 'ASSET01 (2)', 'value': 'ASSET01'}, {'label': 'ASSET02 (2)', 'value': 'ASSET02'}, {'label': 'ASSET03 (2)', 'value': 'ASSET03'}, {'label': 'ASSET04 (2)', 'value': 'ASSET04'}, {'label': 'ASSET05 (2)', 'value': 'ASSET05'}, {'label': 'ASSET06 (2)', 'value': 'ASSET06'}, {'label': 'ASSET07 (2)', 'value': 'ASSET07'}, {'label': 'ASSET08 (2)', 'value': 'ASSET08'}, {'label': 'ASSET09 (2)', 'value': 'ASSET09'}, {'label': 'ASSET10 (2)', 'value': 'ASSET10'}, {'label': 'ASSET11 (2)', 'value': 'ASSET11'}, {'label': 'ASSET12 (2)', 'value': 'ASSET12'}, {'label': 'ASSET13 (2)', 'value': 'ASSET13'}, {'label': 'ASSET14 (2)', 'value': 'ASSET14'}, {'label': 'ASSET15 (2)', 'value': 'ASSET15'}, {'label': 'ASSET16 (2)', 'value': 'ASSET16'}, {'label': 'ASSET17 (2)', 'value': 'ASSET17'}, {'label': 'ASSET18 (2)', 'value': 'ASSET18'}, {'label': 'ASSET19 (2)', 'value': 'ASSET19'}, {'label': 'ASSET20 (2)', 'value': 'ASSET20'}, {'label': 'ASSET21 (2)', 'value': 'ASSET21'}, {'label': 'ASSET22 (2)', 'value': 'ASSET22'}, {'label': 'ASSET23 (2)', 'value': 'ASSET23'}, {'label': 'ASSET24 (2)', 'value': 'ASSET24'}, {'label': 'ASSET25 (2)', 'value': 'ASSET25'}, {'label': 'ASSET26 (2)', 'value': 'ASSET26'}, {'label': 'ASSET27 (2)', 'value': 'ASSET27'}, {'label': 'ASSET28 (2)', 'value': 'ASSET28'}, {'label': 'ASSET29 (2)', 'value': 'ASSET29'}, {'label': 'ASSET30 (2)', 'value': 'ASSET30'}, {'label': 'ASSET31 (2)', 'value': 'ASSET31'}, {'label': 'ASSET32 (2)', 'value': 'ASSET32'}, {'label': 'ASSET33 (2)', 'value': 'ASSET33'}, {'label': 'ASSET34 (2)', 'value': 'ASSET34'}, {'label': 'ASSET35 (2)', 'value': 'ASSET35'}, {'label': 'ASSET36 (2)', 'value': 'ASSET36'}, {'label': 'ASSET37 (2)', 'value': 'ASSET37'}, {'label': 'ASSET38 (2)', 'value': 'ASSET38'}, {'label': 'ASSET39 (2)', 'value': 'ASSET39'}, {'label': 'ASSET40 (2)', 'value': 'ASSET40'}, {'label': 'ASSET41 (2)', 'value': 'ASSET41'}, {'label': 'ASSET42 (2)', 'value': 'ASSET42'}, {'label': 'ASSET43 (2)', 'value': 'ASSET43'}, {'label': 'ASSET44 (2)', 'value': 'ASSET44'}, {'label': 'ASSET45 (2)', 'value': 'ASSET45'}, {'label': 'ASSET46 (2)', 'value': 'ASSET46'}, {'label': 'ASSET47 (2)', 'value': 'ASSET47'}, {'label': 'ASSET48 (2)', 'value': 'ASSET48'}, {'label': 'ASSET49 (2)', 'value': 'ASSET49'}, {'label': 'ASSET50 (2)', 'value': 'ASSET50'}, {'label': 'ASSET51 (2)', 'value': 'ASSET51'}, {'label': 'ASSET52 (2)', 'value': 'ASSET52'}, {'label': 'ASSET53 (2)', 'value': 'ASSET53'}, {'label': 'ASSET54 (2)', 'value': 'ASSET54'}, {'label': 'ASSET55 (2)', 'value': 'ASSET55'}, {'label': 'ASSET56 (2)', 'value': 'ASSET56'}, {'label': 'ASSET57 (2)', 'value': 'ASSET57'}, {'label': 'ASSET58 (2)', 'value': 'ASSET58'}, {'label': 'ASSET59 (2)', 'value': 'ASSET59'}, {'label': 'ASSET60 (2)', 'value': 'ASSET60'}], multi=True, placeholder='Select ticker...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'ticker'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for ticker (type: factor). Total cards now: 12
# [DEBUG FILTERS] Processing total_return (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for total_return (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for total_return: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for total_return (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for total_return: filter_comp=Div([RangeSlider(min=-66.84674812113609, max=129.5915356930863, marks={-66.84674812113609: '-66.85', 129.5915356930863: '129.59', 31.372393785975113: '31.37'}, value=[-66.84674812113609, 129.5915356930863], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'total_return'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for total_return (type: number). Total cards now: 13
# [DEBUG FILTERS] ✓✓✓ FINAL: Returning filter panel with 13 filter cards
# [DEBUG FILTERS] ✓✓✓ FINAL: Card headers: ['a', 'a', 'a', 'c', 'c', 'f', 'm', 'p', 'r', 'r', 's', 't', 't']
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8058
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /assets/style.css?m=1763094107.969347 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/deps/react@16.v2_18_2m1745265411.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_18_2m1745265411.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_18_2m1745265411.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_18_2m1745265411.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v1_6_0m1745265411.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_18_2m1745265411.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_14_3m1745265411.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_14_3m1745265411.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_20m1745265411.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:27] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_13m1745265411.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_favicon.ico?v=2.18.2 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "GET /_dash-component-suites/plotly/package_data/plotly.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:28] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:50] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:51] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:51] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:52] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:53] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:53] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:53] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:53] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:54] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:55] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:03:55] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:03:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:13] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:13] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:04:15] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:15] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:04:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:16] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:04:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:18] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:04:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:18] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:04:18] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:18] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:04:19] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:04:19] "POST /_dash-update-component HTTP/1.1" 204 -

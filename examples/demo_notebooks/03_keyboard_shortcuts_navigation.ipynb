# %% [markdown]
# # Keyboard Shortcuts & Power User Features
#
# This notebook demonstrates the **complete keyboard-driven workflow** for power users.
#
# ## Features Demonstrated
#
# - ⌨️ **Full Keyboard Navigation** - Navigate without touching the mouse
# - 🚀 **Power User Shortcuts** - Boost productivity with hotkeys
# - 🔍 **Quick Search** - Instant filtering with `/` shortcut
# - 📄 **Page Navigation** - Arrow keys, Home/End
# - 🎨 **Layout Control** - +/- to adjust grid size
# - 💾 **State Management** - Ctrl+S to save views
# - ❓ **Built-in Help** - Press `?` for keyboard reference
#
# ## Complete Keyboard Shortcuts
#
# ### Navigation
# - `←` / `→` - Previous/Next page
# - `Home` - Jump to first page
# - `End` - Jump to last page
#
# ### Search
# - `/` - Focus search box
# - `Esc` - Clear search (when in search box)
#
# ### Layout Control
# - `+` or `=` - Increase grid size (more panels per page)
# - `-` or `_` - Decrease grid size (fewer panels per page)
#
# ### View Management
# - `Ctrl+S` - Save current view
# - `Ctrl+R` - Reset all filters
#
# ### Help
# - `?` - Toggle keyboard shortcuts help modal
#
# ---
#
# We'll create a dataset large enough to demonstrate pagination and navigation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from pathlib import Path
import sys
from datetime import datetime, timedelta

sys.path.insert(0, str(Path.cwd().parent.parent))

from trelliscope import Display
from trelliscope.dash_viewer import create_dash_app

np.random.seed(42)

# %% [markdown]
# ## Generate Large Dataset
#
# Create 100 panels to demonstrate pagination and navigation

# %%
# Generate synthetic time series data
n_series = 100
n_points = 365

print(f"Generating {n_series} time series with {n_points} points each...\n")

data_rows = []
categories = ['Technology', 'Finance', 'Healthcare', 'Energy', 'Consumer']
regions = ['North America', 'Europe', 'Asia Pacific', 'Latin America']

start_date = datetime(2023, 1, 1)
dates = [start_date + timedelta(days=i) for i in range(n_points)]

for i in range(n_series):
    # Generate realistic time series with trend + seasonality + noise
    trend = np.linspace(100, 100 + np.random.randn() * 50, n_points)
    seasonality = 20 * np.sin(np.linspace(0, 4 * np.pi, n_points))
    noise = np.random.randn(n_points) * 5
    values = trend + seasonality + noise
    
    # Calculate metrics
    mean_val = values.mean()
    std_val = values.std()
    min_val = values.min()
    max_val = values.max()
    
    # Calculate trend direction
    slope = (values[-1] - values[0]) / n_points
    trend_label = 'Up' if slope > 0.1 else ('Down' if slope < -0.1 else 'Flat')
    
    # Create simple line plot
    fig, ax = plt.subplots(figsize=(8, 4))
    ax.plot(dates, values, linewidth=1.5, color='steelblue')
    ax.fill_between(dates, values, alpha=0.3, color='steelblue')
    ax.set_title(f'Series {i+1}: {categories[i % len(categories)]}', fontsize=12, fontweight='bold')
    ax.set_xlabel('Date')
    ax.set_ylabel('Value')
    ax.grid(True, alpha=0.3)
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    data_rows.append({
        'series_id': f'TS_{i+1:03d}',
        'category': categories[i % len(categories)],
        'region': regions[i % len(regions)],
        'mean': mean_val,
        'std': std_val,
        'min': min_val,
        'max': max_val,
        'trend': trend_label,
        'volatility': 'High' if std_val > 15 else ('Medium' if std_val > 10 else 'Low'),
        'panel': fig
    })
    
    plt.close(fig)
    
    if (i + 1) % 20 == 0:
        print(f"  Generated {i+1}/{n_series} panels...")

df = pd.DataFrame(data_rows)
print(f"\n✓ Generated {len(df)} time series panels")
# Out:
# Generating 100 time series with 365 points each...
#
#   Generated 20/100 panels...
#   Generated 40/100 panels...
#   Generated 60/100 panels...
#   Generated 80/100 panels...
#   Generated 100/100 panels...
#
# ✓ Generated 100 time series panels

# %%
# Preview data
print("DataFrame shape:", df.shape)
print("\nColumns:", list(df.columns))
print("\nValue counts:")
print(f"  Categories: {df['category'].value_counts().to_dict()}")
print(f"  Regions: {df['region'].value_counts().to_dict()}")
print(f"  Trends: {df['trend'].value_counts().to_dict()}")
print(f"  Volatility: {df['volatility'].value_counts().to_dict()}")
# Out:
# DataFrame shape: (100, 10)
#
# Columns: ['series_id', 'category', 'region', 'mean', 'std', 'min', 'max', 'trend', 'volatility', 'panel']
#
# Value counts:
#   Categories: {'Technology': 20, 'Finance': 20, 'Healthcare': 20, 'Energy': 20, 'Consumer': 20}
#   Regions: {'North America': 25, 'Europe': 25, 'Asia Pacific': 25, 'Latin America': 25}
#   Trends: {'Flat': 50, 'Up': 25, 'Down': 25}
#   Volatility: {'High': 73, 'Medium': 27}

# %% [markdown]
# ## Create Display for Keyboard Navigation Demo

# %%
display = (
    Display(
        df,
        name="keyboard_shortcuts_demo",
        description="Power User Features - 100 panels to demonstrate keyboard navigation"
    )
    .set_panel_column("panel")
    .infer_metas()
    .set_default_layout(ncol=3, nrow=2)  # 6 panels per page = ~17 pages
    .set_default_labels(["series_id", "category", "trend", "volatility"])
)

print("✓ Display configured")
print(f"  Panels: {len(df)}")
print(f"  Default layout: 3 cols × 2 rows = 6 panels per page")
print(f"  Approximate pages: {len(df) // 6}")
# Out:
# ✓ Display configured
#   Panels: 100
#   Default layout: 3 cols × 2 rows = 6 panels per page
#   Approximate pages: 16

# %% [markdown]
# ## Launch Viewer - Keyboard Navigation Tutorial
#
# ### 🎯 Step-by-Step Keyboard Workflow
#
# Follow this tutorial to master keyboard-driven navigation:
#
# #### 1️⃣ **Basic Page Navigation** (10 seconds)
# ```
# → → →     Press Right Arrow 3 times (advance 3 pages)
# ← ←       Press Left Arrow 2 times (go back 2 pages)
# End       Press End (jump to last page)
# Home      Press Home (jump to first page)
# ```
#
# #### 2️⃣ **Quick Search** (15 seconds)
# ```
# /              Press / to focus search box
# Technology     Type "Technology" (filters instantly)
# Esc            Press Escape to clear search
# /              Press / again
# High           Type "High" to find high volatility series
# Esc            Clear search
# ```
#
# #### 3️⃣ **Layout Adjustment** (10 seconds)
# ```
# + + +     Press + three times (increase to 4×3 grid = 12 panels)
# - -       Press - twice (decrease back to 3×2 = 6 panels)
# ```
#
# #### 4️⃣ **Filtering Workflow** (20 seconds)
# ```
# 1. Use mouse to set filters:
#    - Category: Select "Technology"
#    - Trend: Select "Up"
#    - Volatility: Select "High"
# 2. Navigate filtered results:
#    → →       Browse pages
#    Ctrl+R    Reset all filters
# ```
#
# #### 5️⃣ **Save and Restore Views** (15 seconds)
# ```
# 1. Apply some filters (e.g., Category = "Finance")
# 2. Press Ctrl+S
# 3. Enter view name: "Finance Only"
# 4. Reset filters with Ctrl+R
# 5. Use Views dropdown to reload "Finance Only"
# ```
#
# #### 6️⃣ **Help Reference** (5 seconds)
# ```
# ?     Press ? to open keyboard shortcuts help
# ?     Press ? again to close
# ```
#
# ### ⚡ Pro Tips
#
# - **Never leave the keyboard**: Complete workflows without using mouse
# - **Muscle memory**: After a few times, these shortcuts become second nature
# - **Combine shortcuts**: `/` + search + `→` for rapid exploration
# - **Grid size control**: Use `+/-` to find your preferred density
# - **View snapshots**: `Ctrl+S` to bookmark interesting filter combinations
#
# ### 📊 Performance Benefits
#
# With 100 panels across ~17 pages:
# - **Mouse navigation**: ~30 seconds to reach last page (17 clicks)
# - **Keyboard navigation**: ~2 seconds to reach last page (press `End`)
# - **Search filter**: Instant results vs manual scanning
#
# ---
#
# The viewer opens at http://localhost:8056
#
# **Try the complete workflow above to experience the power of keyboard-driven data exploration!**

# %%
app = create_dash_app(display)
app.run(debug=False, host='127.0.0.1', port=8056)
# Out:
# Rendering 100 panels...
#   Rendered panel 0: 0.png
#   Rendered panel 1: 1.png
#   Rendered panel 2: 2.png
#   Rendered panel 3: 3.png
#   Rendered panel 4: 4.png
#   Rendered panel 5: 5.png
#   Rendered panel 6: 6.png
#   Rendered panel 7: 7.png
#   Rendered panel 8: 8.png
#   Rendered panel 9: 9.png
#   Rendered panel 10: 10.png
#   Rendered panel 11: 11.png
#   Rendered panel 12: 12.png
#   Rendered panel 13: 13.png
#   Rendered panel 14: 14.png
#   Rendered panel 15: 15.png
#   Rendered panel 16: 16.png
#   Rendered panel 17: 17.png
#   Rendered panel 18: 18.png
#   Rendered panel 19: 19.png
#   Rendered panel 20: 20.png
#   Rendered panel 21: 21.png
#   Rendered panel 22: 22.png
#   Rendered panel 23: 23.png
#   Rendered panel 24: 24.png
#   Rendered panel 25: 25.png
#   Rendered panel 26: 26.png
#   Rendered panel 27: 27.png
#   Rendered panel 28: 28.png
#   Rendered panel 29: 29.png
#   Rendered panel 30: 30.png
#   Rendered panel 31: 31.png
#   Rendered panel 32: 32.png
#   Rendered panel 33: 33.png
#   Rendered panel 34: 34.png
#   Rendered panel 35: 35.png
#   Rendered panel 36: 36.png
#   Rendered panel 37: 37.png
#   Rendered panel 38: 38.png
#   Rendered panel 39: 39.png
#   Rendered panel 40: 40.png
#   Rendered panel 41: 41.png
#   Rendered panel 42: 42.png
#   Rendered panel 43: 43.png
#   Rendered panel 44: 44.png
#   Rendered panel 45: 45.png
#   Rendered panel 46: 46.png
#   Rendered panel 47: 47.png
#   Rendered panel 48: 48.png
#   Rendered panel 49: 49.png
#   Rendered panel 50: 50.png
#   Rendered panel 51: 51.png
#   Rendered panel 52: 52.png
#   Rendered panel 53: 53.png
#   Rendered panel 54: 54.png
#   Rendered panel 55: 55.png
#   Rendered panel 56: 56.png
#   Rendered panel 57: 57.png
#   Rendered panel 58: 58.png
#   Rendered panel 59: 59.png
#   Rendered panel 60: 60.png
#   Rendered panel 61: 61.png
#   Rendered panel 62: 62.png
#   Rendered panel 63: 63.png
#   Rendered panel 64: 64.png
#   Rendered panel 65: 65.png
#   Rendered panel 66: 66.png
#   Rendered panel 67: 67.png
#   Rendered panel 68: 68.png
#   Rendered panel 69: 69.png
#   Rendered panel 70: 70.png
#   Rendered panel 71: 71.png
#   Rendered panel 72: 72.png
#   Rendered panel 73: 73.png
#   Rendered panel 74: 74.png
#   Rendered panel 75: 75.png
#   Rendered panel 76: 76.png
#   Rendered panel 77: 77.png
#   Rendered panel 78: 78.png
#   Rendered panel 79: 79.png
#   Rendered panel 80: 80.png
#   Rendered panel 81: 81.png
#   Rendered panel 82: 82.png
#   Rendered panel 83: 83.png
#   Rendered panel 84: 84.png
#   Rendered panel 85: 85.png
#   Rendered panel 86: 86.png
#   Rendered panel 87: 87.png
#   Rendered panel 88: 88.png
#   Rendered panel 89: 89.png
#   Rendered panel 90: 90.png
#   Rendered panel 91: 91.png
#   Rendered panel 92: 92.png
#   Rendered panel 93: 93.png
#   Rendered panel 94: 94.png
#   Rendered panel 95: 95.png
#   Rendered panel 96: 96.png
#   Rendered panel 97: 97.png
#   Rendered panel 98: 98.png
#   Rendered panel 99: 99.png
#   Generated index.html viewer at trelliscope_output/keyboard_shortcuts_demo
# 🚀 Dash viewer starting on http://127.0.0.1:8056
# 📊 Display: keyboard_shortcuts_demo
# 📈 Panels: 100
#
# ✨ Opening browser...
#  * Serving Flask app 'trelliscope.dash_viewer.app'
#  * Debug mode: off
# [DEBUG FILTERS] Total filterable_metas: 9
# [DEBUG FILTERS] Meta varnames: ['category', 'max', 'mean', 'min', 'region', 'series_id', 'std', 'trend', 'volatility']
# [DEBUG FILTERS] Meta types: ['factor', 'number', 'number', 'number', 'factor', 'factor', 'number', 'factor', 'factor']
# [DEBUG FILTERS] cog_data columns: ['series_id', 'category', 'region', 'mean', 'std', 'min', 'max', 'trend', 'volatility', 'panelKey', 'panel', 'category_label', 'region_label', 'series_id_label', 'trend_label', 'volatility_label', '_panel_full_path', '_panel_type']
# [DEBUG FILTERS] Factor category: using label column category_label
# [DEBUG FILTERS] >>> About to call create_filter_component for category (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for category: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for category (type: factor)
# [DEBUG FILTERS] category dropdown has 5 options
# [DEBUG FILTERS] category component id: {'type': 'filter', 'varname': 'category'}
# [DEBUG FILTERS] >>> About to check if filter_comp for category: filter_comp=Dropdown(options=[{'label': 'Consumer (20)', 'value': 'Consumer'}, {'label': 'Energy (20)', 'value': 'Energy'}, {'label': 'Finance (20)', 'value': 'Finance'}, {'label': 'Healthcare (20)', 'value': 'Healthcare'}, {'label': 'Technology (20)', 'value': 'Technology'}], multi=True, placeholder='Select category...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'category'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for category (type: factor). Total cards now: 1
# [DEBUG FILTERS] Processing max (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for max (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for max: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for max (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for max: filter_comp=Div([RangeSlider(min=113.80590802559934, max=227.42950863545863, marks={113.80590802559934: '113.81', 227.42950863545863: '227.43', 170.61770833052898: '170.62'}, value=[113.80590802559934, 227.42950863545863], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'max'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for max (type: number). Total cards now: 2
# [DEBUG FILTERS] Processing mean (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for mean (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for mean: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for mean (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for mean: filter_comp=Div([RangeSlider(min=41.5071608072457, max=160.01325667805085, marks={41.5071608072457: '41.51', 160.01325667805085: '160.01', 100.76020874264827: '100.76'}, value=[41.5071608072457, 160.01325667805085], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'mean'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for mean (type: number). Total cards now: 3
# [DEBUG FILTERS] Processing min (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for min (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for min: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for min (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for min: filter_comp=Div([RangeSlider(min=-34.341540148250814, max=99.86399937181989, marks={-34.341540148250814: '-34.34', 99.86399937181989: '99.86', 32.761229611784536: '32.76'}, value=[-34.341540148250814, 99.86399937181989], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'min'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for min (type: number). Total cards now: 4
# [DEBUG FILTERS] Factor region: using label column region_label
# [DEBUG FILTERS] >>> About to call create_filter_component for region (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for region: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for region (type: factor)
# [DEBUG FILTERS] region dropdown has 4 options
# [DEBUG FILTERS] region component id: {'type': 'filter', 'varname': 'region'}
# [DEBUG FILTERS] >>> About to check if filter_comp for region: filter_comp=Dropdown(options=[{'label': 'Asia Pacific (25)', 'value': 'Asia Pacific'}, {'label': 'Europe (25)', 'value': 'Europe'}, {'label': 'Latin America (25)', 'value': 'Latin America'}, {'label': 'North America (25)', 'value': 'North America'}], multi=True, placeholder='Select region...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'region'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for region (type: factor). Total cards now: 5
# [DEBUG FILTERS] Factor series_id: using label column series_id_label
# [DEBUG FILTERS] >>> About to call create_filter_component for series_id (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for series_id: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for series_id (type: factor)
# [DEBUG FILTERS] series_id dropdown has 100 options
# [DEBUG FILTERS] series_id component id: {'type': 'filter', 'varname': 'series_id'}
# [DEBUG FILTERS] >>> About to check if filter_comp for series_id: filter_comp=Dropdown(options=[{'label': 'TS_001 (1)', 'value': 'TS_001'}, {'label': 'TS_002 (1)', 'value': 'TS_002'}, {'label': 'TS_003 (1)', 'value': 'TS_003'}, {'label': 'TS_004 (1)', 'value': 'TS_004'}, {'label': 'TS_005 (1)', 'value': 'TS_005'}, {'label': 'TS_006 (1)', 'value': 'TS_006'}, {'label': 'TS_007 (1)', 'value': 'TS_007'}, {'label': 'TS_008 (1)', 'value': 'TS_008'}, {'label': 'TS_009 (1)', 'value': 'TS_009'}, {'label': 'TS_010 (1)', 'value': 'TS_010'}, {'label': 'TS_011 (1)', 'value': 'TS_011'}, {'label': 'TS_012 (1)', 'value': 'TS_012'}, {'label': 'TS_013 (1)', 'value': 'TS_013'}, {'label': 'TS_014 (1)', 'value': 'TS_014'}, {'label': 'TS_015 (1)', 'value': 'TS_015'}, {'label': 'TS_016 (1)', 'value': 'TS_016'}, {'label': 'TS_017 (1)', 'value': 'TS_017'}, {'label': 'TS_018 (1)', 'value': 'TS_018'}, {'label': 'TS_019 (1)', 'value': 'TS_019'}, {'label': 'TS_020 (1)', 'value': 'TS_020'}, {'label': 'TS_021 (1)', 'value': 'TS_021'}, {'label': 'TS_022 (1)', 'value': 'TS_022'}, {'label': 'TS_023 (1)', 'value': 'TS_023'}, {'label': 'TS_024 (1)', 'value': 'TS_024'}, {'label': 'TS_025 (1)', 'value': 'TS_025'}, {'label': 'TS_026 (1)', 'value': 'TS_026'}, {'label': 'TS_027 (1)', 'value': 'TS_027'}, {'label': 'TS_028 (1)', 'value': 'TS_028'}, {'label': 'TS_029 (1)', 'value': 'TS_029'}, {'label': 'TS_030 (1)', 'value': 'TS_030'}, {'label': 'TS_031 (1)', 'value': 'TS_031'}, {'label': 'TS_032 (1)', 'value': 'TS_032'}, {'label': 'TS_033 (1)', 'value': 'TS_033'}, {'label': 'TS_034 (1)', 'value': 'TS_034'}, {'label': 'TS_035 (1)', 'value': 'TS_035'}, {'label': 'TS_036 (1)', 'value': 'TS_036'}, {'label': 'TS_037 (1)', 'value': 'TS_037'}, {'label': 'TS_038 (1)', 'value': 'TS_038'}, {'label': 'TS_039 (1)', 'value': 'TS_039'}, {'label': 'TS_040 (1)', 'value': 'TS_040'}, {'label': 'TS_041 (1)', 'value': 'TS_041'}, {'label': 'TS_042 (1)', 'value': 'TS_042'}, {'label': 'TS_043 (1)', 'value': 'TS_043'}, {'label': 'TS_044 (1)', 'value': 'TS_044'}, {'label': 'TS_045 (1)', 'value': 'TS_045'}, {'label': 'TS_046 (1)', 'value': 'TS_046'}, {'label': 'TS_047 (1)', 'value': 'TS_047'}, {'label': 'TS_048 (1)', 'value': 'TS_048'}, {'label': 'TS_049 (1)', 'value': 'TS_049'}, {'label': 'TS_050 (1)', 'value': 'TS_050'}, {'label': 'TS_051 (1)', 'value': 'TS_051'}, {'label': 'TS_052 (1)', 'value': 'TS_052'}, {'label': 'TS_053 (1)', 'value': 'TS_053'}, {'label': 'TS_054 (1)', 'value': 'TS_054'}, {'label': 'TS_055 (1)', 'value': 'TS_055'}, {'label': 'TS_056 (1)', 'value': 'TS_056'}, {'label': 'TS_057 (1)', 'value': 'TS_057'}, {'label': 'TS_058 (1)', 'value': 'TS_058'}, {'label': 'TS_059 (1)', 'value': 'TS_059'}, {'label': 'TS_060 (1)', 'value': 'TS_060'}, {'label': 'TS_061 (1)', 'value': 'TS_061'}, {'label': 'TS_062 (1)', 'value': 'TS_062'}, {'label': 'TS_063 (1)', 'value': 'TS_063'}, {'label': 'TS_064 (1)', 'value': 'TS_064'}, {'label': 'TS_065 (1)', 'value': 'TS_065'}, {'label': 'TS_066 (1)', 'value': 'TS_066'}, {'label': 'TS_067 (1)', 'value': 'TS_067'}, {'label': 'TS_068 (1)', 'value': 'TS_068'}, {'label': 'TS_069 (1)', 'value': 'TS_069'}, {'label': 'TS_070 (1)', 'value': 'TS_070'}, {'label': 'TS_071 (1)', 'value': 'TS_071'}, {'label': 'TS_072 (1)', 'value': 'TS_072'}, {'label': 'TS_073 (1)', 'value': 'TS_073'}, {'label': 'TS_074 (1)', 'value': 'TS_074'}, {'label': 'TS_075 (1)', 'value': 'TS_075'}, {'label': 'TS_076 (1)', 'value': 'TS_076'}, {'label': 'TS_077 (1)', 'value': 'TS_077'}, {'label': 'TS_078 (1)', 'value': 'TS_078'}, {'label': 'TS_079 (1)', 'value': 'TS_079'}, {'label': 'TS_080 (1)', 'value': 'TS_080'}, {'label': 'TS_081 (1)', 'value': 'TS_081'}, {'label': 'TS_082 (1)', 'value': 'TS_082'}, {'label': 'TS_083 (1)', 'value': 'TS_083'}, {'label': 'TS_084 (1)', 'value': 'TS_084'}, {'label': 'TS_085 (1)', 'value': 'TS_085'}, {'label': 'TS_086 (1)', 'value': 'TS_086'}, {'label': 'TS_087 (1)', 'value': 'TS_087'}, {'label': 'TS_088 (1)', 'value': 'TS_088'}, {'label': 'TS_089 (1)', 'value':  ...
# [DEBUG FILTERS] ✓ Added card for series_id (type: factor). Total cards now: 6
# [DEBUG FILTERS] Processing std (type: number): found in cog_data
# [DEBUG FILTERS] >>> About to call create_filter_component for std (type: number)
# [DEBUG FILTERS] >>> create_filter_component returned for std: <class 'dash.html.Div.Div'>
# [DEBUG FILTERS] Created filter component for std (type: number)
# [DEBUG FILTERS] >>> About to check if filter_comp for std: filter_comp=Div([RangeSlider(min=13.547787903835202, max=41.90715978816776, marks={13.547787903835202: '13.55', 41.90715978816776: '41.91', 27.72747384600148: '27.73'}, value=[13.547787903835202, 41.90715978816776], allowCross=False, tooltip={'placement': 'bottom', 'always_visible': False}, id={'type': 'filter', 'varname': 'std'})]), is not None=True
# [DEBUG FILTERS] ✓ Added card for std (type: number). Total cards now: 7
# [DEBUG FILTERS] Factor trend: using label column trend_label
# [DEBUG FILTERS] >>> About to call create_filter_component for trend (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for trend: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for trend (type: factor)
# [DEBUG FILTERS] trend dropdown has 3 options
# [DEBUG FILTERS] trend component id: {'type': 'filter', 'varname': 'trend'}
# [DEBUG FILTERS] >>> About to check if filter_comp for trend: filter_comp=Dropdown(options=[{'label': 'Down (25)', 'value': 'Down'}, {'label': 'Flat (50)', 'value': 'Flat'}, {'label': 'Up (25)', 'value': 'Up'}], multi=True, placeholder='Select trend...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'trend'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for trend (type: factor). Total cards now: 8
# [DEBUG FILTERS] Factor volatility: using label column volatility_label
# [DEBUG FILTERS] >>> About to call create_filter_component for volatility (type: factor)
# [DEBUG FILTERS] >>> create_filter_component returned for volatility: <class 'dash.dcc.Dropdown.Dropdown'>
# [DEBUG FILTERS] Created filter component for volatility (type: factor)
# [DEBUG FILTERS] volatility dropdown has 2 options
# [DEBUG FILTERS] volatility component id: {'type': 'filter', 'varname': 'volatility'}
# [DEBUG FILTERS] >>> About to check if filter_comp for volatility: filter_comp=Dropdown(options=[{'label': 'High (73)', 'value': 'High'}, {'label': 'Medium (27)', 'value': 'Medium'}], multi=True, placeholder='Select volatility...', style={'fontSize': '13px'}, id={'type': 'filter', 'varname': 'volatility'}), is not None=True
# [DEBUG FILTERS] ✓ Added card for volatility (type: factor). Total cards now: 9
# [DEBUG FILTERS] ✓✓✓ FINAL: Returning filter panel with 9 filter cards
# [DEBUG FILTERS] ✓✓✓ FINAL: Card headers: ['c', 'm', 'm', 'm', 'r', 's', 's', 't', 'v']
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8056
# Press CTRL+C to quit
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /assets/style.css?m=1763094107.969347 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/deps/react@16.v2_18_2m1745265411.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/deps/react-dom@16.v2_18_2m1745265411.14.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/deps/polyfill@7.v2_18_2m1745265411.12.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/deps/prop-types@15.v2_18_2m1745265411.8.1.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash_bootstrap_components/_components/dash_bootstrap_components.v1_6_0m1745265411.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/dash-renderer/build/dash_renderer.v2_18_2m1745265411.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/dcc/dash_core_components.v2_14_3m1745265411.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/dcc/dash_core_components-shared.v2_14_3m1745265411.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/html/dash_html_components.v2_0_20m1745265411.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/dash_table/bundle.v5_2_13m1745265411.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/dcc/async-slider.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "GET /_favicon.ico?v=2.18.2 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:52] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:55] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:55] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:56] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:57] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:00:57] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:00:57] "POST /_dash-update-component HTTP/1.1" 204 -
# 127.0.0.1 - - [14/Nov/2025 21:01:00] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Nov/2025 21:01:00] "POST /_dash-update-component HTTP/1.1" 204 -
